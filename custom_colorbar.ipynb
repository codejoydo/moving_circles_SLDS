# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import cmasher as cmr

fig, ax = plt.subplots(figsize=(1, 5), layout='constrained')

cmap = cmr.horizon_r#mpl.cm.cool
norm = mpl.colors.Normalize(vmin=0, vmax=1)

fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=ax, 
    orientation='vertical', 
    label=''
)
ax.tick_params('both',labelsize=20)
fig.savefig(
    f"figures/fig2_colorbar.eps", dpi=600, bbox_inches="tight"
)

# %%
fig, ax = plt.subplots(figsize=(1.2, 5), layout='constrained')

cmap = mpl.cm.PiYG
norm = mpl.colors.Normalize(vmin=-0.46, vmax=0.46)

fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=ax, 
    orientation='vertical', 
    label=''
)
ax.tick_params('both',labelsize=20)
fig.savefig(
    f"figures/fig7b_colorbar.eps", dpi=600, bbox_inches="tight"
)

# %%
fig, ax = plt.subplots(figsize=(0.5, 5), layout='constrained')

cmap = mpl.cm.PiYG
norm = mpl.colors.Normalize(vmin=-0.71, vmax=0.71)

fig.colorbar(
    mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
    cax=ax, 
    orientation='vertical', 
    label=''
)
ax.tick_params('both',labelsize=20)
fig.savefig(
    f"figures/fig7c_colorbar.eps", dpi=600, bbox_inches="tight"
)
